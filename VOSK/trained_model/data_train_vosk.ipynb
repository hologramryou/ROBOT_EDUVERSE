# %%
# !apt-get install sox libsox-fmt-all ffmpeg
# !pip install vosk
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   libao-common libao4 libid3tag0 libmad0 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-ao libsox-fmt-base libsox-fmt-mp3 libsox-fmt-oss libsox-fmt-pulse libsox3 libwavpack1
# Suggested packages:
#   libaudio2 libsndio6.1
# The following NEW packages will be installed:
#   libao-common libao4 libid3tag0 libmad0 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-all
#   libsox-fmt-alsa libsox-fmt-ao libsox-fmt-base libsox-fmt-mp3 libsox-fmt-oss libsox-fmt-pulse
#   libsox3 libwavpack1 sox
# 0 upgraded, 16 newly installed, 0 to remove and 49 not upgraded.
# Need to get 800 kB of archives.
# After this operation, 2,533 kB of additional disk space will be used.
# ...

# %%
# !git clone https://github.com/alphacep/vosk-api
# !git clone https://github.com/kaldi-asr/kaldi
# Out:
# Cloning into 'vosk-api'...
# remote: Enumerating objects: 4351, done.
# remote: Counting objects: 100% (1178/1178), done.
# remote: Compressing objects: 100% (501/501), done.
# remote: Total 4351 (delta 749), reused 933 (delta 610), pack-reused 3173 (from 1)
# Receiving objects: 100% (4351/4351), 14.12 MiB | 20.26 MiB/s, done.
# Resolving deltas: 100% (2403/2403), done.
# Cloning into 'kaldi'...
# remote: Enumerating objects: 116025, done.
# remote: Counting objects: 100% (186/186), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 116025 (delta 82), reused 166 (delta 72), pack-reused 115839 (from 1)
# Receiving objects: 100% (116025/116025), 122.50 MiB | 24.41 MiB/s, done.
# Resolving deltas: 100% (89392/89392), done.

# %%
# !wget http://www.openslr.org/resources/12/dev-clean.tar.gz
# !tar -xvzf dev-clean.tar.gz
# Out:
# --2024-09-27 06:17:04--  http://www.openslr.org/resources/12/dev-clean.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: http://openslr.elda.org/resources/12/dev-clean.tar.gz [following]
# --2024-09-27 06:17:04--  http://openslr.elda.org/resources/12/dev-clean.tar.gz
# Resolving openslr.elda.org (openslr.elda.org)... 141.94.109.138, 2001:41d0:203:ad8a::
# Connecting to openslr.elda.org (openslr.elda.org)|141.94.109.138|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 337926286 (322M) [application/x-gzip]
# Saving to: ‘dev-clean.tar.gz’
#
# dev-clean.tar.gz    100%[===================>] 322.27M  31.2MB/s    in 11s
#
# 2024-09-27 06:17:15 (30.2 MB/s) - ‘dev-clean.tar.gz’ saved [337926286/337926286]
#
# LibriSpeech/LICENSE.TXT
# LibriSpeech/README.TXT
# LibriSpeech/CHAPTERS.TXT
# ...

# %%
# %cd /content/kaldi/tools
# !make -j 4
# %cd /content/kaldi/src
# !./configure --shared
# !make depend; make -j 4
# Out:
# /content/kaldi/tools
# extras/check_dependencies.sh
# if [ -d "" ]; then \
#   cp -p "/cub-1.8.0.tar.gz" .; \
# else \
#   wget -nv -T 10 -t 3 -O cub-1.8.0.tar.gz \
#     https://github.com/NVlabs/cub/archive/1.8.0.tar.gz; \
# fi
# if [ -d "" ]; then \
#   cp -p "/openfst-1.8.3.tar.gz" .; \
# else \
#   wget -nv -T 10 -t 1 http://www.openfst.org/twiki/pub/FST/FstDownload/openfst-1.8.3.tar.gz || \
#   wget -nv -T 10 -t 3 -c https://www.openslr.org/resources/2/openfst-1.8.3.tar.gz; \
# fi
# if [ -d '' ]; then \
#   cp -p '/sctk-20159b5.tar.gz' .; \
# else \
#   wget -nv -T 10 -t 3 -O sctk-20159b5.tar.gz \
#     https://github.com/usnistgov/SCTK/archive/20159b5.tar.gz; \
# fi
# extras/check_dependencies.sh: neither libtoolize nor glibtoolize is installed
# extras/check_dependencies.sh: python2.7 is not installed
# extras/check_dependencies.sh: python3 present
# extras/check_dependencies.sh: Configuring python
# ...

# %%
# Feature extraction, e.g. MFCCs
# !steps/make_mfcc.sh --nj 4 --cmd run.pl data/train exp/make_mfcc/train mfcc
# !steps/compute_cmvn_stats.sh data/train exp/make_mfcc/train mfcc
# Out:
# /bin/bash: line 1: steps/make_mfcc.sh: No such file or directory
# /bin/bash: line 1: steps/compute_cmvn_stats.sh: No such file or directory

# %%
# !steps/train_mono.sh --nj 4 --cmd run.pl data/train data/lang exp/mono
# Out:
# /bin/bash: line 1: steps/train_mono.sh: No such file or directory

# %%
# !git clone https://github.com/kpu/kenlm
# %cd kenlm
# !mkdir -p build && cd build
# !cmake ..
# !make -j 4
# Out:
# Cloning into 'kenlm'...
# remote: Enumerating objects: 14170, done.
# remote: Counting objects: 100% (483/483), done.
# remote: Compressing objects: 100% (337/337), done.
# remote: Total 14170 (delta 166), reused 408 (delta 132), pack-reused 13687 (from 1)
# Receiving objects: 100% (14170/14170), 5.91 MiB | 16.50 MiB/s, done.
# Resolving deltas: 100% (8046/8046), done.
# /content/kaldi/src/kenlm
# CMake Warning:
#   Ignoring extra path from command line:
#
#    ".."
#
#
# CMake Error: The source directory "/content/kaldi/src" does not appear to contain CMakeLists.txt.
# Specify --help for usage, or press the help button on the CMake GUI.
# make: *** No targets specified and no makefile found.  Stop.

# %%
# !./lmplz -o 3 < text_data.txt > lm.arpa
# Out:
# /bin/bash: line 1: text_data.txt: No such file or directory

# %%
# !wget https://alphacephei.com/vosk/models/vosk-model-small-en-us-0.15.zip
# !unzip vosk-model-small-en-us-0.15.zip -d vosk-model
# Out:
# --2024-09-27 06:23:11--  https://alphacephei.com/vosk/models/vosk-model-small-en-us-0.15.zip
# Resolving alphacephei.com (alphacephei.com)... 188.40.21.16, 2a01:4f8:13a:279f::2
# Connecting to alphacephei.com (alphacephei.com)|188.40.21.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41205931 (39M) [application/zip]
# Saving to: ‘vosk-model-small-en-us-0.15.zip’
#
# vosk-model-small-en 100%[===================>]  39.30M  18.7MB/s    in 2.1s
#
# 2024-09-27 06:23:13 (18.7 MB/s) - ‘vosk-model-small-en-us-0.15.zip’ saved [41205931/41205931]
#
# Archive:  vosk-model-small-en-us-0.15.zip
#    creating: vosk-model/vosk-model-small-en-us-0.15/
#    creating: vosk-model/vosk-model-small-en-us-0.15/am/
#   inflating: vosk-model/vosk-model-small-en-us-0.15/am/final.mdl
#    creating: vosk-model/vosk-model-small-en-us-0.15/graph/
#   inflating: vosk-model/vosk-model-small-en-us-0.15/graph/disambig_tid.int
# ...

# %%
from google.colab import files
audio_file = files.upload()  # This will open a dialog to upload files
# Out:
#      <input type="file" id="files-aef37909-3fde-4ceb-ba42-24f56b9634d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aef37909-3fde-4ceb-ba42-24f56b9634d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from vosk import Model, KaldiRecognizer
import wave

model = Model(lang="en-us")
wf = wave.open("test.wav", "rb")
rec = KaldiRecognizer(model, wf.getframerate())

while True:
    data = wf.readframes(4000)
    if len(data) == 0:
        break
    if rec.AcceptWaveform(data):
        print(rec.Result())
    else:
        print(rec.PartialResult())
# Out:
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : "one"
# }
# {
#   "partial" : "one zero"
# }
# {
#   "partial" : "one zero zero"
# }
# {
#   "partial" : "one zero zero"
# }
# {
#   "partial" : "one zero zero zero"
# }
# {
#   "partial" : "one zero zero zero one"
# }
# {
#   "partial" : "one zero zero zero one"
# }
# {
#   "partial" : "one zero zero zero one"
# }
# {
#   "partial" : "one zero zero zero one"
# }
# {
#   "text" : "one zero zero zero one"
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : "nah no"
# }
# {
#   "partial" : "nah no"
# }
# {
#   "partial" : "nah no to"
# }
# {
#   "partial" : "nah no to i know"
# }
# {
#   "partial" : "nah no to i know"
# }
# {
#   "partial" : "nah no to i know"
# }
# {
#   "text" : "nah no to i know"
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : "zero"
# ...
